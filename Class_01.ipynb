# %% [markdown]
# <a href="https://colab.research.google.com/github/dhruv-sathesh/Computational-Statistics-/blob/main/Class_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
print("hello class")
# Out:
# hello class

# %% [markdown]
# We are learning computational statistics

# %%
a = 5
b= 10
c = a+b
c
# Out:
# 15

# %%
ad_expense = [20,10,50,21,31]
sales = [500,750,932,340,1248]
plt.plot(ad_expense,sales)
